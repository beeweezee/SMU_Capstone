# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import warnings
import model_report as mr
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
file_info = "C:\\Users\\blgai\\OneDrive\\Documents\\School\\SMU\\Courses\\Fall 2021\\Capstone A\Data\\cleaned_chunked_v2.csv"
df = pd.read_csv(file_info, sep='\t')

# %%
df.head()
# Out:
#                        url  code category language  \
# 0        *://BLAZINHERB.CA   200       dr       en
# 1  *://THEHONEYPOTSTORE.CA   200       dr       en
# 2            *://AMANTE.CA   200       dr       en
# 3          *://CANNAFLY.CA   200       dr       en
# 4              *://GRON.VC   200       dr       en
#
#                                                title  \
# 0                                        Blazin Herb
# 1  The Honey Pot Cannabis and Medical Marijuana p...
# 2  Amante Organics - Licensed Certified Organic C...
# 3                                           Cannafly
# 4                                      Grøn Ventures
#
#                                              summary  \
# 0                              The Diamond High Crew
# 1  The Honey Pot Hamilton Ontario, provides canna...
# 2              np-template-header-footer-from-plugin
# 3                                           Cannafly
# 4  We are backing businesses and brands with pote...
#
#                                            key_words  \
# 0                                        Blazin herb
# 1  The Honey Pot ,Georgia Peach Cannabis and Medi...
# 2  Organic Cannabis, Certified Organic, Weed, Org...
# 3  Marijuana, cannabis, medical marijuana, dispen...
# 4  cannabis vc, cannabis venture capital, gron ve...
#
#                                              content  \
# 0  Blazin Herb THC Edibles Concentrates Flower/bu...
# 1  The Honey Pot Home About Us F.A.Q.'s About The...
# 2  Amante Organics LOCAL | ORGANIC | SUSTAINABLE ...
# 3  Vancouver's Premium Mobile Medicinal Cannabis ...
# 4  GRØN VENTURES 4675 MacArthur Ct, 15th Floor, N...
#
#                                             combined  \
# 0  Blazin Herb The Diamond High Crew Blazin herb ...
# 1  The Honey Pot Cannabis and Medical Marijuana p...
# 2  Amante Organics - Licensed Certified Organic C...
# 3  Cannafly Cannafly Marijuana, cannabis, medical...
# 4  Grøn Ventures We are backing businesses and br...
#
#                                                nouns  \
# 0  [('Blazin', 0, 6, 'PROPN'), ('Herb', 7, 11, 'P...
# 1  [('Honey', 4, 9, 'PROPN'), ('Pot', 10, 13, 'PR...
# 2  [('Amante', 0, 6, 'PROPN'), ('Organics', 7, 15...
# 3  [('Cannafly', 0, 8, 'PROPN'), ('Cannafly', 9, ...
# 4  [('Grøn', 0, 4, 'PROPN'), ('Ventures', 5, 13, ...
#
#                                            compounds  \
# 0  [('Blazin Herb', 0, 11, 'COMPOUND'), ('Diamond...
# 1  [('Honey Pot Cannabis', 4, 22, 'COMPOUND'), ('...
# 2  [('Amante Organics -', 0, 17, 'COMPOUND'), ('O...
# 3  [('marijuana legalization', 70, 92, 'COMPOUND'...
# 4  [('Grøn Ventures', 0, 13, 'COMPOUND'), ('marke...
#
#                                           comp_nouns  \
# 0  {'Read', 'Picks', 'DIAMOND', 'bud', 'THC', 'So...
# 1  {'appetite', 'Stress', 'Muscle', 'Hepatitis C'...
# 2  {'nations', 'Rights Reserved', "a'mante", 'Lic...
# 3  {'chilliwack', 'Connoisseurs', 'THC', 'industr...
# 4  {'marijuana', 'Beach', 'Newport', 'ventures', ...
#
#                                      flat_comp_nouns  \
# 0  {'Read', 'Picks', 'DIAMOND', 'bud', 'THC', 'So...
# 1  {'appetite', 'Stress', 'Muscle', 'Hepatitis C'...
# 2  {'nations', 'Rights Reserved', "a'mante", 'Lic...
# 3  {'chilliwack', 'Connoisseurs', 'THC', 'industr...
# 4  {'marijuana', 'Beach', 'Newport', 'ventures', ...
#
#                                     clean_comp_nouns
# 0  read picks diamond bud thc social sleep club r...
# 1  appetite stress muscle hepatitis c hamilton hi...
# 2  nation rights reserved amante licensed np head...
# 3  chilliwack connoisseurs thc industry death bub...
# 4  marijuana beach newport venture ct ventures ma...

# %%
df.groupby(df.category).size()
# Out:
# category
# bu    11731
# dr     1595
# ed     3894
# mk     8775
# os     6789
# sp     2535
# sx     6557
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
#get 10% holdout set
train_corpus, holdout_corpus, train_label, holdout_label = train_test_split(df['clean_comp_nouns'], 
                                                                           df['category'],
                                                                           test_size=.10,random_state=1234)

#get 80% train and 20% test sets
train_corpus, test_corpus, train_label, test_label = train_test_split(train_corpus,
                                                                      train_label,
                                                                      test_size=.2225,random_state=1234) #.9 * .2225 = .20

train_corpus.shape, test_corpus.shape, holdout_corpus.shape
# Out:
# ((29302,), (8386,), (4188,))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#build BOW features on train corpus
tv = TfidfVectorizer(use_idf=True, min_df=0.0,max_df=1.0, norm="l2",smooth_idf=True)
tv_train_features = tv.fit_transform(train_corpus)
#transform test corpus into features
tv_test_features = tv.transform(test_corpus)
#transform holdout corpus into features
tv_holdout_features = tv.transform(holdout_corpus)

print('TFIDF model:> Train features shape:',tv_train_features.shape,'Test features shape:',tv_test_features.shape,'Holdout features shape:',tv_holdout_features.shape)
# Out:
# TFIDF model:> Train features shape: (29302, 344693) Test features shape: (8386, 344693) Holdout features shape: (4188, 344693)

# %%
#Let's find the top important features and analyze them

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X_opt=SelectKBest(chi2, k=1500)
tv_train_features_trimmed = X_opt.fit_transform(tv_train_features, train_label)
tv_train_features_trimmed.shape
# Out:
# (29302, 1500)

# %%
#create a data frame that includes all features and whether or not they are deemed important by feature_selection
feat_imp = pd.DataFrame(list(zip(tv.get_feature_names(),X_opt.get_support().tolist())),columns = ['Features','Important'])
feat_imp[feat_imp.Important == True]
# Out:
#            Features  Important
# 1118         abroad       True
# 1331       academic       True
# 1345      academics       True
# 1352        academy       True
# 1558    accessories       True
# ...             ...        ...
# 341278        young       True
# 341545        youth       True
# 342144        zaden       True
# 342324      zambeza       True
# 342346     zamnesia       True
#
# [1500 rows x 2 columns]

# %%
#Now we can grab the important features so that we can select only the important features from the sparse matrix created by TfidfVectorizer
imp_Feats_array = np.array(feat_imp[feat_imp.Important == True].index)

# %%
#Now we can pull only the important features out of the original train, test, and holdout matrices
tv_train_features_sub = tv_train_features[:,imp_Feats_array]
tv_test_features_sub = tv_test_features[:,imp_Feats_array]
tv_holdout_features_sub = tv_holdout_features[:,imp_Feats_array]

#Examine the new shapes of the sub-selected features
print('TFIDF model:> Train features shape:',tv_train_features_sub.shape,'Test features shape:',tv_test_features_sub.shape,'Holdout features shape:',tv_holdout_features_sub.shape)
# Out:
# TFIDF model:> Train features shape: (29302, 1500) Test features shape: (8386, 1500) Holdout features shape: (4188, 1500)

# %%
#SVM
from sklearn.svm import LinearSVC
#note I have weighted the drug and sex class to help ensure we do not misclassify sites as these categories 
#useing the parameter class_weight
svm = LinearSVC(penalty='l2',C=1.0,class_weight={'dr':8,'sx':10},random_state=1234)
svm.fit(tv_train_features_sub,train_label)
# Out:
# LinearSVC(class_weight={'dr': 8, 'sx': 10}, random_state=1234)

# %%
svm_tfidf_cv_scores = cross_val_score(svm,tv_train_features_sub,train_label,cv=5)
svm_tfidf_cv_mean_score = np.mean(svm_tfidf_cv_scores)
print('CV Accuracy (5-fold):',svm_tfidf_cv_scores)
print('Mean CV Accuracy:',svm_tfidf_cv_mean_score)
# Out:
# CV Accuracy (5-fold): [0.84064153 0.84780754 0.85068259 0.84744027 0.84675768]
# Mean CV Accuracy: 0.8466659232399275

# %%
svm_tfidf_test_score = svm.score(tv_test_features_sub,test_label)
print('Test Accuracy:',svm_tfidf_test_score)
# Out:
# Test Accuracy: 0.8511805389935607

# %%
import model_evaluation_utils as meu
svm_predictions = svm.predict(tv_test_features_sub)
meu.get_metrics(true_labels=test_label,predicted_labels=svm_predictions)
# Out:
# Accuracy: 0.8512
# Precision: 0.8517
# Recall: 0.8512
# F1 Score: 0.8511

# %%
unique_classes = list(set(test_label))
meu.display_classification_report(true_labels=test_label,predicted_labels=svm_predictions,classes=unique_classes)
# Out:
#               precision    recall  f1-score   support
#
#           mk       0.74      0.74      0.74      1709
#           bu       0.83      0.87      0.85      2355
#           ed       0.91      0.86      0.89       783
#           sx       0.98      0.99      0.99      1345
#           os       0.83      0.78      0.80      1393
#           dr       0.97      0.95      0.96       307
#           sp       0.90      0.88      0.89       494
#
#     accuracy                           0.85      8386
#    macro avg       0.88      0.87      0.87      8386
# weighted avg       0.85      0.85      0.85      8386

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(test_label,svm_predictions,labels=['os','ed','dr','sp','mk','sx','bu'])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
mr.plot_confusion_matrix(cnf_matrix, classes=['os','ed','dr','sp','mk','sx','bu'],
                      title='Confusion matrix, TFIDF on Clean Chunked')
# Out:
# Confusion matrix, without normalization
# [[1085   19    6    8  174    5   96]
#  [   7  676    0   10   28    1   61]
#  [   6    0  293    0    3    2    3]
#  [  11    8    0  434   29    7    5]
#  [ 132   17    3   24 1270    4  259]
#  [   1    0    0    1    4 1338    1]
#  [  67   19    1    7  217    2 2042]]

# %%
from sklearn.calibration import CalibratedClassifierCV

svm = LinearSVC(penalty='l2',C=1.0,class_weight={'dr':8,'sx':10},random_state=1234)
clf = CalibratedClassifierCV(svm)
clf.fit(tv_train_features_sub,train_label)
y_proba = clf.predict_proba(tv_test_features_sub)

labels_dict = dict(zip(df.category,df.category))
target_names = sorted(list(labels_dict.values()))

mr.plot_roc_curve(labels=test_label, predictions=y_proba, x_lim=[0.0,0.5], y_lim=[0.5,1.0], target_names=target_names)

# %%
clf_predictions = clf.predict(tv_test_features_sub)

# %%
cnf_matrix = confusion_matrix(test_label,clf_predictions,labels=['os','ed','dr','sp','mk','sx','bu'])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
mr.plot_confusion_matrix(cnf_matrix, classes=['os','ed','dr','sp','mk','sx','bu'],
                      title='Confusion matrix, TFIDF on Clean Chunked')
# Out:
# Confusion matrix, without normalization
# [[1085   19    2    9  179    3   96]
#  [   8  676    0   10   30    1   58]
#  [   9    1  285    0    6    1    5]
#  [  11    7    0  437   32    2    5]
#  [ 129   19    1   24 1288    2  246]
#  [   1    0    0    1    9 1332    2]
#  [  66   24    1    6  229    1 2028]]

# %%
meu.get_metrics(true_labels=test_label,predicted_labels=clf_predictions)
# Out:
# Accuracy: 0.8503
# Precision: 0.8519
# Recall: 0.8503
# F1 Score: 0.8508

# %%
meu.display_classification_report(true_labels=test_label,predicted_labels=clf_predictions,classes=unique_classes)
# Out:
#               precision    recall  f1-score   support
#
#           mk       0.73      0.75      0.74      1709
#           bu       0.83      0.86      0.85      2355
#           ed       0.91      0.86      0.88       783
#           sx       0.99      0.99      0.99      1345
#           os       0.83      0.78      0.80      1393
#           dr       0.99      0.93      0.96       307
#           sp       0.90      0.88      0.89       494
#
#     accuracy                           0.85      8386
#    macro avg       0.88      0.87      0.87      8386
# weighted avg       0.85      0.85      0.85      8386

# %%
df_test_results = pd.DataFrame(list(zip(test_corpus,test_label,clf_predictions, y_proba)),columns = ['terms','actual_label','predicted_label','probability'])
df_test_results['match'] = np.where(df_test_results['actual_label']==df_test_results['predicted_label'],1,0)

# %%
pd.set_option('display.max_colwidth', None)
df_test_results[(df_test_results.predicted_label == 'sx') & (df_test_results.match == 0)]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 332                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 1787                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 2208                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 2715                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 3041                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 5109                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 5841                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 6605                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 6926                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 7236  delilah mather ira mary j forbes extremo casa annie weston swing antebellum second sparks donde shannon popp mcwilliams napier jackie maggie sombras al atardecer lobo lori corey tabke natalie stephens jensen los apartado tanya ii sudamericana violet winston sociedad escritores enamorados reyes de elaine colley conveniencia tiffany especial penny profecia novelas kane kimberly mcnaught j r forster carpenter ramsay versatil linda gordon libros libro medidas wallace susanne jameson signature c kristi jennie lyons editor fechas mary busbee jackie metzger perrin amerindios fiona harrington oculta way del romance historico sally marsh pasion los pagos sinclair gena silver maisey young semidioses fantasmas hombres lobo leyendas bela mi tierra esta katy real agregar lowry alexis stacy conrad clasicos patt buck sagas de la novela karen marie monk nicole georgette gayle sed janice mayo laurie dixie brownley lisa jackson showalter packs kristin hannay laura kirk desde siempre edades biset ediciones universo libreria universoromance libreria libreria pappano miranda kelleher tarling whitefeather kim leclaire mills alexandra howard adriana romances guerra mundial antebellum suspenso marian kramer escritores sarah mccauley olivia armintrout julie kahn jeanne rivers seda terciopelo por pasadizo digital harbison sagas belleza rutledge maravilla harlen anne la ciudad esmeralda briggs tori carrion deseo kathryn cass leslie lamb salier agregar reynard simulado carin alex sacerdoti constitucion dean diane chambers alison richmond neil bobby lanzamientos lynn vincent tess judy clare matrimonio j r warren kent joan elliott popp melissa garlock amanda browning julia quinn roman mira heather graham desmelena cassie arnold wilson tierra lois grey j kent chantelle shayne maris southwick estela valerie patrick hamilton lee wilks candice moments veronica lucas harmex natalie fox grasso eve simmons chastain hannah toomey artes christine taylor marcelo putney de piso de vista realeza reconciliacion sue urian digital elena olivia darcy mariana gail linz cuando agregar banks connelly betty hern gardner ryanne rita hewitt lori atreverse martin julia james debbi raye kinsale pandora pandora nuevo claudia helen r myracle erin burton dalessandro heather meredith weger megan mayberry madeline hutchinson l marie adrian tu lori hannah mcintyre kathleen woods frontera hauf jump atkins andrea noble virginia bradley grant radley carol marsh camucha tierra coffman levy cynthia ryan antiguedad antiguo kathleen kramer mallery kenner alice sharpe emily mckinney catherine marbel sherryl napoleonicas niroli la erotica cambiantes oculta jill sharon patricia broadrick narrativa hechizos poderes capacidade leandra logan gabriela marinelli bolsillo cindy gerritsen brenda ruth lark mas jazmin amistad fox escudero jane potter lectores claridad debolsillo edaf vecinos greiman tara kristin gale jessica hart premiados prostitucion puntos robb webber equivocada rayanne brenda harper atencion al cliente como comprar formas de pago formas gastos de jane featherstone gerritsen sandra martyn exclusivos noches corin summers cheryl daly garnier roth j roberts benita brown gaelen forbes shirley hale etherington rita raleigh joanna nicholas angela seller trapp jan kristine cameron gabriel lynn enoch jennie adeline b j james american revolucion hart gibson cautiva donna grasso oneill erin mccarty susan cross por conquistar lisa kohake megan veronica julie orwig tango saskia jayne ann krentz pace novela trish morgan wilkins armstrong corin templeton sally carlyle meredith bradford maria correo grandes raye morgan amor aventura apasionada b beaumont kieran las anne paula gimenez viviana dark moments sombras super bianca super jazmin super julia super novela super tentacion superromance talisman macomber michelle logan lauren napier carroll anabella frankel envio bernard contacto makepeace estrellas cheryl anne porter ingrid susan elizabeth pickart lewis ciencia estadounidense lin judith m ...
#
#      actual_label predicted_label  \
# 332            os              sx
# 1787           sp              sx
# 2208           os              sx
# 2715           bu              sx
# 3041           mk              sx
# 5109           ed              sx
# 5841           mk              sx
# 6605           dr              sx
# 6926           sp              sx
# 7236           os              sx
#
#                                                                                                                                                       probability  \
# 332   [0.03973451939500899, 0.00041339864442996364, 4.447718884985536e-07, 0.003999633638189386, 0.016065250217926874, 1.408312030184855e-05, 0.9397726702122545]
# 1787           [0.07618217872829475, 0.0026465465274054965, 0.01017415200977101, 0.2665898618892813, 0.1364835666608452, 0.16512940411505456, 0.3427942900693478]
# 2208        [0.12491274896320023, 0.001187243467418897, 0.01898866497987539, 0.12836727362658434, 0.03577471074198017, 0.0031767661662026802, 0.6875925920547382]
# 2715          [0.07081260319983197, 0.004069527808582958, 0.03366890631745099, 0.1988717399962457, 0.07326097557282416, 0.006178177838926031, 0.6131380692661383]
# 3041   [0.18691242742623831, 9.473891472792604e-05, 0.007710454631109807, 0.003346022289788643, 0.0008600084862076078, 0.0009225197684782546, 0.8001538284834494]
# 5109         [0.009992916687014285, 0.003472469899536679, 0.3177316024951693, 0.04715028546787291, 0.04631972414155412, 0.004022168924991802, 0.5713108323838609]
# 5841               [0.247885142057417, 0.00498353400804182, 0.05531540914879655, 0.21635017449822547, 0.19029968235683886, 0.035324062127969, 0.2498419958027113]
# 6605           [0.08504995885704736, 0.3005656352974694, 0.01600425087405292, 0.02511872410781756, 0.1644180413095865, 0.005165770025748221, 0.40367761952827796]
# 6926           [0.08929516038676617, 0.008604737150389223, 0.13561967376480769, 0.2161602999627648, 0.10859346344359833, 0.21627359106533853, 0.2254530742263353]
# 7236            [0.19557036359290925, 0.005333031517418036, 0.1276497130099597, 0.1262217680560877, 0.16768398007746432, 0.05061337727239721, 0.3269277664737637]
#
#       match
# 332       0
# 1787      0
# 2208      0
# 2715      0
# 3041      0
# 5109      0
# 5841      0
# 6605      0
# 6926      0
# 7236      0

# %%
df_test_results[(df_test_results.predicted_label == 'sx') & (df_test_results.match == 0)].groupby('actual_label').size()
# Out:
# actual_label
# bu    1
# dr    1
# ed    1
# mk    2
# os    3
# sp    2
# dtype: int64
